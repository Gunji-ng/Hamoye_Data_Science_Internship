# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
A = [1,2,3,4,5,6]
B = [13,21,34]

# %%
A.extend(B)
A
# Out:
# [1, 2, 3, 4, 5, 6, 13, 21, 34]

# %%
np.identity(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
np.eye(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
fuel_data_df = pd.read_csv('https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv', error_bad_lines=False)
fuel_data_df.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
fuel_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29523 entries, 0 to 29522
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   record_id                     29523 non-null  object
#  1   utility_id_ferc1              29523 non-null  int64
#  2   report_year                   29523 non-null  int64
#  3   plant_name_ferc1              29523 non-null  object
#  4   fuel_type_code_pudl           29523 non-null  object
#  5   fuel_unit                     29343 non-null  object
#  6   fuel_qty_burned               29523 non-null  float64
#  7   fuel_mmbtu_per_unit           29523 non-null  float64
#  8   fuel_cost_per_unit_burned     29523 non-null  float64
#  9   fuel_cost_per_unit_delivered  29523 non-null  float64
#  10  fuel_cost_per_mmbtu           29523 non-null  float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 2.5+ MB

# %%
fuel_data_df['fuel_type_code_pudl'].nunique()
# Out:
# 6

# %%
fuel_data_by_fuel_type_df = fuel_data_df.groupby('fuel_type_code_pudl').mean()
fuel_data_by_fuel_type_df
# Out:
#                      utility_id_ferc1  report_year  fuel_qty_burned  \
# fuel_type_code_pudl
# coal                       115.637534  2004.623143     1.903473e+06
# gas                        124.122062  2005.978060     4.843183e+06
# nuclear                    107.397311  2002.970660     5.454838e+06
# oil                        113.236235  2007.195933     6.311677e+04
# other                      110.467066  2001.700599     2.948137e+06
# waste                      154.253968  2005.650794     1.171914e+05
#
#                      fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# fuel_type_code_pudl
# coal                           20.762780                  67.421830
# gas                             1.021913                  13.659397
# nuclear                        17.582120                4955.157002
# oil                             5.814377                 168.877086
# other                           0.572752                  18.253856
# ...

# %%
fuel_data_by_fuel_type_df['fuel_cost_per_unit_burned'].sort_values()
# Out:
# fuel_type_code_pudl
# gas          13.659397
# other        18.253856
# waste        19.518122
# coal         67.421830
# oil         168.877086
# nuclear    4955.157002
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
fuel_data_df.describe()
# Out:
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      29523.000000  29523.000000     2.952300e+04         29523.000000
# mean         118.601836   2005.806050     2.622119e+06             8.492111
# std           74.178353      7.025483     9.118004e+06            10.600220
# min            1.000000   1994.000000     1.000000e+00             0.000001
# 25%           55.000000   2000.000000     1.381700e+04             1.024000
# 50%          122.000000   2006.000000     2.533220e+05             5.762694
# 75%          176.000000   2012.000000     1.424034e+06            17.006000
# max          514.000000   2018.000000     5.558942e+08           341.260000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count               29523.000000                  2.952300e+04
# mean                  208.649031                  9.175704e+02
# std                  2854.490090                  6.877593e+04
# ...

# %%
fuel_data_df.fuel_mmbtu_per_unit.describe()
# Out:
# count    29523.000000
# mean         8.492111
# std         10.600220
# min          0.000001
# 25%          1.024000
# 50%          5.762694
# 75%         17.006000
# max        341.260000
# Name: fuel_mmbtu_per_unit, dtype: float64

# %%
fuel_data_df.fuel_qty_burned.kurtosis()
# Out:
# 651.3694501337732

# %%
fuel_data_df.fuel_qty_burned.kurt()
# Out:
# 651.3694501337732

# %%
fuel_data_df.fuel_qty_burned.skew()
# Out:
# 15.851495469109503

# %%
fuel_data_df.shape[0]
# Out:
# (29523, 11)

# %%
fuel_data_df['fuel_unit'].isnull().value_counts()
# Out:
# False    29343
# True       180
# Name: fuel_unit, dtype: int64

# %%
fuel_data_df.shape[0]
# Out:
# 29523

# %%
fuel_data_df['fuel_unit'].isnull().value_counts()[1]
# Out:
# 180

# %%
fuel_data_df['fuel_unit'].isnull().value_counts()[1]/fuel_data_df.shape[0]
# Out:
# 0.00609694136774718

# %%
fuel_data_df['fuel_unit'].value_counts()
# Out:
# mcf       11354
# ton        8958
# bbl        7998
# gramsU      464
# mmbtu       180
# kgU         110
# mwhth       100
# mwdth        95
# gal          84
# Name: fuel_unit, dtype: int64

# %%
fuel_data_df.corr()
# Out:
#                               utility_id_ferc1  report_year  fuel_qty_burned  \
# utility_id_ferc1                      1.000000     0.093323        -0.057447
# report_year                           0.093323     1.000000         0.012952
# fuel_qty_burned                      -0.057447     0.012952         1.000000
# fuel_mmbtu_per_unit                  -0.066946    -0.110853        -0.080946
# fuel_cost_per_unit_burned            -0.037863     0.013599        -0.018535
# fuel_cost_per_unit_delivered         -0.016414    -0.014043        -0.003551
# fuel_cost_per_mmbtu                   0.006122     0.010261        -0.001896
#
#                               fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# utility_id_ferc1                        -0.066946                  -0.037863
# report_year                             -0.110853                   0.013599
# fuel_qty_burned                         -0.080946                  -0.018535
# ...

# %%
fuel_data_df.corr()['fuel_cost_per_unit_burned'].sort_values()
# Out:
# utility_id_ferc1               -0.037863
# fuel_qty_burned                -0.018535
# fuel_mmbtu_per_unit            -0.010034
# fuel_cost_per_mmbtu            -0.000437
# fuel_cost_per_unit_delivered    0.011007
# report_year                     0.013599
# fuel_cost_per_unit_burned       1.000000
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
fuel_data_df.query('fuel_type_code_pudl == "coal" & report_year == 1994')
# Out:
#                     record_id  utility_id_ferc1  report_year  \
# 0       f1_fuel_1994_12_1_0_7                 1         1994
# 1      f1_fuel_1994_12_1_0_10                 1         1994
# 2       f1_fuel_1994_12_2_0_1                 2         1994
# 3       f1_fuel_1994_12_2_0_7                 2         1994
# 5      f1_fuel_1994_12_2_0_13                 2         1994
# ...                       ...               ...          ...
# 1224  f1_fuel_1994_12_45_0_10                45         1994
# 1227   f1_fuel_1994_12_45_1_1                45         1994
# 1229   f1_fuel_1994_12_45_1_7                45         1994
# 1230  f1_fuel_1994_12_45_1_10                45         1994
# 1232   f1_fuel_1994_12_45_2_1                45         1994
#
#           plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                 rockport                coal       ton        5377489.0
# 1     rockport total plant                coal       ton       10486945.0
# ...

# %%
fuel_data_df.query('fuel_type_code_pudl == "coal" & report_year == 1998')
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 4618     f1_fuel_1998_12_1_0_7                 1         1998
# 4619    f1_fuel_1998_12_1_0_10                 1         1998
# 4620     f1_fuel_1998_12_4_0_1                 4         1998
# 4622     f1_fuel_1998_12_4_0_4                 4         1998
# 4624     f1_fuel_1998_12_6_0_1                 6         1998
# ...                        ...               ...          ...
# 5708  f1_fuel_1998_12_145_0_10               145         1998
# 5710  f1_fuel_1998_12_145_0_13               145         1998
# 5712   f1_fuel_1998_12_145_1_1               145         1998
# 5714   f1_fuel_1998_12_145_1_4               145         1998
# 5716   f1_fuel_1998_12_145_1_7               145         1998
#
#           plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 4618    rockport total aeg                coal       ton        4965881.0
# ...

# %%
fuel_data_df.query('fuel_type_code_pudl == "coal" & report_year == 1994')['fuel_cost_per_unit_burned'].sum()
# Out:
# 14984.572000000002

# %%
fuel_data_df.query('fuel_type_code_pudl == "coal" & report_year == 1998')['fuel_cost_per_unit_burned'].sum()
# Out:
# 11902.597

# %%
fuel_data_df.query('fuel_type_code_pudl == "coal" & report_year == 1994')['fuel_cost_per_unit_burned'].mean()
# Out:
# 31.546467368421077

# %%
fuel_data_df.query('fuel_type_code_pudl == "coal" & report_year == 1998')['fuel_cost_per_unit_burned'].mean()
# Out:
# 27.61623433874713

# %%
(fuel_data_df.query('fuel_type_code_pudl == "coal" & report_year == 1998')['fuel_cost_per_unit_burned'].sum() - fuel_data_df.query('fuel_type_code_pudl == "coal" & report_year == 1994')['fuel_cost_per_unit_burned'].sum())/fuel_data_df.query('fuel_type_code_pudl == "coal" & report_year == 1994')['fuel_cost_per_unit_burned'].sum()
# Out:
# -0.20567654518260528

# %%
(fuel_data_df.query('fuel_type_code_pudl == "coal" & report_year == 1998')['fuel_cost_per_unit_burned'].mean() - fuel_data_df.query('fuel_type_code_pudl == "coal" & report_year == 1994')['fuel_cost_per_unit_burned'].mean())/fuel_data_df.query('fuel_type_code_pudl == "coal" & report_year == 1994')['fuel_cost_per_unit_burned'].mean()
# Out:
# -0.12458551963280119

# %%
fuel_data_df.groupby('report_year').mean()
# Out:
#              utility_id_ferc1  fuel_qty_burned  fuel_mmbtu_per_unit  \
# report_year
# 1994               106.120648     2.724018e+06            10.638098
# 1995               110.139051     3.712067e+06            10.644830
# 1996               108.714154     2.544754e+06            10.778041
# 1997               108.366545     2.813503e+06            10.247632
# 1998               109.845528     3.267453e+06            10.704964
# 1999               108.222857     3.281281e+06            10.558885
# 2000               111.083758     2.472032e+06             9.224475
# 2001               113.521386     2.321402e+06             8.371469
# 2002               120.354357     2.145645e+06             8.304833
# 2003               123.300578     1.888622e+06             8.403746
# 2004               121.123322     1.782547e+06             8.332425
# 2005               121.028369     1.768876e+06             8.135972
# 2006               117.178600     1.957264e+06             8.138090
# ...

# %%
fuel_data_df.groupby('report_year').mean()['fuel_cost_per_unit_delivered'].sort_values()
# Out:
# report_year
# 1999       25.551627
# 1995       32.735269
# 2006       38.657484
# 2005       41.438184
# 2007       43.325023
# 2017       46.196861
# 2002       47.594361
# 2003       55.663493
# 2008       58.588197
# 2011       59.774667
# 2001       60.050396
# 2012       60.994502
# 1994       63.636060
# 2010       91.862105
# 2016      103.901761
# 2004      139.524275
# 2013      172.307591
# 2014      192.737183
# 1998      287.154420
# 2015      326.535511
# 2018      499.269966
# 2009      652.694163
# 2000      985.362877
# 1996     9196.705948
# 1997    11140.197239
# Name: fuel_cost_per_unit_delivered, dtype: float64
