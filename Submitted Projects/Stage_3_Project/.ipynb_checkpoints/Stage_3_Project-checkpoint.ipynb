# %%
#importing libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, auc
import xgboost as xgb
import lightgbm as lgb

# %matplotlib inline

# %%
#loading the 'Electrical grid stability simulated data' csv file into a Pandas DataFrame
#and viewing 20 random samples

grid_stability_df = pd.read_csv('Data_for_UCI_named.csv')
grid_stability_df.sample(20)
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 2151  4.885594  4.492654  0.813042  6.896235  3.699702 -0.850125 -1.131750
# 1227  5.517582  8.957591  1.436065  6.313365  4.291516 -1.722768 -1.345658
# 3909  7.966910  7.938467  7.390104  9.480514  3.122507 -1.542557 -0.640890
# 9718  9.972112  6.168310  8.725427  8.359631  3.731736 -1.496079 -1.035089
# 7143  7.178384  2.676985  5.853651  8.591054  3.987141 -1.605152 -1.473204
# 7959  6.930732  2.522304  4.498266  7.400319  3.769992 -1.592009 -0.603540
# 5727  8.404053  4.118025  9.214318  3.143636  3.549255 -0.682075 -1.351051
# 8874  6.631798  3.064766  5.433139  3.167381  2.505402 -1.024246 -0.800847
# 7079  2.206536  8.541561  9.466997  3.843354  3.241298 -1.008874 -0.661776
# 2890  4.714897  1.125952  3.342714  7.394299  4.918754 -1.926761 -1.038290
# 3912  4.436839  3.544308  6.799332  9.104475  3.397087 -1.598914 -0.691865
# 1802  3.783991  2.123360  0.561618  6.481342  4.216664 -1.120745 -1.119174
# 7866  3.979233  4.953997  9.201204  6.722893  4.220731 -1.377312 -1.145516
# 8213  8.049094  7.168937  0.752654  8.467433  4.466420 -1.604314 -0.892664
# 8169  7.538009  4.702949  2.084779  2.545229  4.627076 -1.914902 -1.284495
# 2719  0.729291  1.987899  8.523200  5.208317  3.542207 -0.577101 -1.996357
# 2701  3.303592  6.775539  2.529117  7.720828  4.405119 -1.581119 -1.581286
# 6948  7.042526  6.406949  1.257005  4.660547  3.270594 -0.761347 -0.810780
# 8596  9.830469  5.596505  9.199474  2.878822  3.776559 -0.797709 -1.827294
# 8420  9.259172  1.101893  6.855748  8.009986  3.516102 -0.935940 -0.752055
#
#             p4        g1        g2        g3        g4      stab     stabf
# 2151 -1.717827  0.142690  0.838390  0.449986  0.806175  0.023433  unstable
# 1227 -1.223091  0.684754  0.566761  0.496002  0.444886  0.026825  unstable
# 3909 -0.939060  0.303979  0.641188  0.908932  0.791567  0.081697  unstable
# 9718 -1.200568  0.407976  0.211980  0.096953  0.803821  0.034775  unstable
# 7143 -0.908785  0.612802  0.270193  0.947136  0.700026  0.067487  unstable
# 7959 -1.574443  0.682631  0.801097  0.960071  0.697409  0.074447  unstable
# 5727 -1.516129  0.860027  0.350346  0.571203  0.809138  0.047358  unstable
# 8874 -0.680309  0.169195  0.868736  0.714346  0.524641  0.037733  unstable
# 7079 -1.570648  0.688398  0.485899  0.124639  0.730437 -0.011381    stable
# 2890 -1.953703  0.967877  0.315758  0.686775  0.339957  0.027589  unstable
# 3912 -1.106307  0.475573  0.809231  0.551680  0.645709  0.049600  unstable
# 1802 -1.976745  0.295335  0.384226  0.535711  0.760425 -0.022789    stable
# 7866 -1.697904  0.239293  0.857724  0.292296  0.252985  0.017793  unstable
# 8213 -1.969442  0.965634  0.918362  0.818956  0.827460  0.063618  unstable
# 8169 -1.427678  0.877621  0.158697  0.751360  0.165247 -0.003386    stable
# 2719 -0.968749  0.746242  0.469059  0.851370  0.320876 -0.025552    stable
# 2701 -1.242714  0.960772  0.439139  0.650788  0.794466  0.047960  unstable
# 6948 -1.698467  0.953290  0.535183  0.357693  0.486756  0.046316  unstable
# 8596 -1.151556  0.465811  0.454270  0.600146  0.987644  0.032367  unstable
# 8420 -1.828107  0.313584  0.584524  0.280867  0.351083 -0.021491    stable

# %%
#checking the DataFrame for null fields and also the Dtype of each feature

grid_stability_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tau1    10000 non-null  float64
#  1   tau2    10000 non-null  float64
#  2   tau3    10000 non-null  float64
#  3   tau4    10000 non-null  float64
#  4   p1      10000 non-null  float64
#  5   p2      10000 non-null  float64
#  6   p3      10000 non-null  float64
#  7   p4      10000 non-null  float64
#  8   g1      10000 non-null  float64
#  9   g2      10000 non-null  float64
#  10  g3      10000 non-null  float64
#  11  g4      10000 non-null  float64
#  12  stab    10000 non-null  float64
#  13  stabf   10000 non-null  object
# dtypes: float64(13), object(1)
# memory usage: 1.1+ MB

# %%
#checking for common stats of each feature

grid_stability_df.describe()
# Out:
#                tau1          tau2          tau3          tau4            p1  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       5.250000      5.250001      5.250004      5.249997      3.750000
# std        2.742548      2.742549      2.742549      2.742556      0.752160
# min        0.500793      0.500141      0.500788      0.500473      1.582590
# 25%        2.874892      2.875140      2.875522      2.874950      3.218300
# 50%        5.250004      5.249981      5.249979      5.249734      3.751025
# 75%        7.624690      7.624893      7.624948      7.624838      4.282420
# max        9.999469      9.999837      9.999450      9.999443      5.864418
#
#                  p2            p3            p4            g1            g2  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      -1.250000     -1.250000     -1.250000      0.525000      0.525000
# std        0.433035      0.433035      0.433035      0.274256      0.274255
# min       -1.999891     -1.999945     -1.999926      0.050009      0.050053
# 25%       -1.624901     -1.625025     -1.624960      0.287521      0.287552
# 50%       -1.249966     -1.249974     -1.250007      0.525009      0.525003
# 75%       -0.874977     -0.875043     -0.875065      0.762435      0.762490
# max       -0.500108     -0.500072     -0.500025      0.999937      0.999944
#
#                  g3            g4          stab
# count  10000.000000  10000.000000  10000.000000
# mean       0.525000      0.525000      0.015731
# std        0.274255      0.274255      0.036919
# min        0.050054      0.050028     -0.080760
# 25%        0.287514      0.287494     -0.015557
# 50%        0.525015      0.525002      0.017142
# 75%        0.762440      0.762433      0.044878
# max        0.999982      0.999930      0.109403

# %%
#creating a Scaler

scaler = StandardScaler()

# %%
#checking the number of occurences of each class of the target variable

grid_stability_df.stabf.value_counts()
# Out:
# unstable    6380
# stable      3620
# Name: stabf, dtype: int64

# %%
grid_stability_df.isna().sum()
# Out:
# tau1     0
# tau2     0
# tau3     0
# tau4     0
# p1       0
# p2       0
# p3       0
# p4       0
# g1       0
# g2       0
# g3       0
# g4       0
# stab     0
# stabf    0
# dtype: int64

# %%
X = grid_stability_df.drop(columns=['stab', 'stabf'])
X
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0     2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1     9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2     8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3     0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4     3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  2.930406  9.487627  2.376523  6.187797  3.343416 -0.658054 -1.449106
# 9996  3.392299  1.274827  2.954947  6.894759  4.349512 -1.663661 -0.952437
# 9997  2.364034  2.842030  8.776391  1.008906  4.299976 -1.380719 -0.943884
# 9998  9.631511  3.994398  2.757071  7.821347  2.514755 -0.966330 -0.649915
# 9999  6.530527  6.781790  4.349695  8.673138  3.492807 -1.390285 -1.532193
#
#             p4        g1        g2        g3        g4
# 0    -1.723086  0.650456  0.859578  0.887445  0.958034
# 1    -1.255012  0.413441  0.862414  0.562139  0.781760
# 2    -0.920492  0.163041  0.766689  0.839444  0.109853
# 3    -0.997374  0.446209  0.976744  0.929381  0.362718
# 4    -0.554305  0.797110  0.455450  0.656947  0.820923
# ...        ...       ...       ...       ...       ...
# 9995 -1.236256  0.601709  0.779642  0.813512  0.608385
# 9996 -1.733414  0.502079  0.567242  0.285880  0.366120
# 9997 -1.975373  0.487838  0.986505  0.149286  0.145984
# 9998 -0.898510  0.365246  0.587558  0.889118  0.818391
# 9999 -0.570329  0.073056  0.505441  0.378761  0.942631
#
# [10000 rows x 12 columns]

# %%
y = grid_stability_df['stabf']
y
# Out:
# 0       unstable
# 1         stable
# 2       unstable
# 3       unstable
# 4       unstable
#           ...
# 9995    unstable
# 9996      stable
# 9997      stable
# 9998    unstable
# 9999    unstable
# Name: stabf, Length: 10000, dtype: object

# %%
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
X_scaled
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0    -0.835374 -0.791317  1.141704  1.652103  0.017397  1.079405 -0.017078
# 1     1.478297 -0.126705 -0.803111 -1.415043  1.752124 -1.593619 -1.438158
# 2     1.357093  1.312140 -0.803499 -1.471504 -0.458492  0.098253 -0.062840
# 3    -1.653138  0.882289 -0.278354 -1.060901  0.284250  0.513904 -1.591046
# 4    -0.771543  0.860108 -0.111670  1.680114 -0.298075  0.287450 -1.376343
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995 -0.845823  1.545219 -1.047793  0.341961 -0.540582  1.367041 -0.459815
# 9996 -0.677397 -1.449518 -0.836875  0.599749  0.797094 -0.955307  0.687190
# 9997 -1.052346 -0.878049  1.285871 -1.546478  0.731231 -0.301880  0.706942
# 9998  1.597686 -0.457846 -0.909029  0.937621 -1.642346  0.655109  1.385835
# 9999  0.466935  0.558555 -0.328291  1.248220 -0.341956 -0.323974 -0.651695
#
#             p4        g1        g2        g3        g4
# 0    -1.092545  0.457467  1.220013  1.321628  1.579026
# 1    -0.011575 -0.406791  1.230354  0.135424  0.936256
# 2     0.760963 -1.319852  0.881299  1.146596 -1.513802
# 3     0.583414 -0.287304  1.647250  1.474543 -0.591750
# 4     1.606636  0.992226 -0.253610  0.481133  1.079063
# ...        ...       ...       ...       ...       ...
# 9995  0.031739  0.279714  0.928533  1.052035  0.304055
# 9996 -1.116396 -0.083579  0.154031 -0.871936 -0.579344
# 9997 -1.675175 -0.135508  1.682844 -1.370013 -1.382054
# 9998  0.811729 -0.582529  0.228110  1.327730  1.069829
# 9999  1.569629 -1.647977 -0.071321 -0.533251  1.522860
#
# [10000 rows x 12 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=1)

# %%
X_train_scaled = X_train
X_train_scaled
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 2694  0.366829 -0.987306  0.647135  1.541166 -0.292654  0.058010  1.297355
# 5140 -0.065424  0.087606  1.030365 -1.636848  0.626079 -0.070658 -1.506156
# 2568 -1.469483  1.295950 -0.501646  1.161001 -0.180786  0.486738  0.684583
# 3671  0.819863  0.527857  1.293979 -1.139053 -0.818238 -0.766503  1.525620
# 7427  0.665110 -1.426660  0.310221  0.914944 -1.626168  0.756237  1.425821
# ...        ...       ...       ...       ...       ...       ...       ...
# 2895  1.551548  0.005620 -1.174290  1.012368 -0.399196  0.755743 -0.638100
# 7813  1.015828 -0.225150 -1.484895 -1.474993  0.456319 -0.734891  0.993118
# 905   0.657290 -0.724160 -1.401705 -0.274374 -0.011490  1.434079 -0.364759
# 5192 -0.060078 -1.261653 -1.007730 -0.875798 -0.784885  0.824691  0.518548
# 235  -1.474850  0.636317  0.248269 -0.994065  1.967934 -1.166355 -0.734221
#
#             p4        g1        g2        g3        g4
# 2694 -0.847041  0.157604  0.340586  0.586122  0.492587
# 5140  0.489346 -0.297128 -1.559781  1.429232 -1.443061
# 2568 -0.857305  1.397865  1.453443 -1.043314  0.492837
# 3671  0.662121 -0.963287  1.363773  1.603523  0.275663
# 7427  0.642515  1.675819  0.696765  1.137423 -1.312122
# ...        ...       ...       ...       ...       ...
# 2895  0.575741 -1.214751  0.314675 -1.622632 -0.636988
# 7813 -1.050832 -1.099815 -0.755649  0.735203 -0.304039
# 905  -1.049362  1.251838  0.293777 -1.547578  0.810673
# 5192  0.020067 -0.186269 -0.388303 -0.724719  1.668195
# 235  -1.517628  1.228703 -1.174994  1.179153  0.783957
#
# [8000 rows x 12 columns]

# %%
X_test_scaled = X_test
X_test_scaled
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 9953  0.593593 -0.414300  1.497501  1.112068  0.407885 -1.495265 -0.786538
# 3850  0.201589  0.372435 -0.189054 -0.521485 -0.226600 -1.061121  0.421440
# 4962 -1.080437 -0.315364 -0.882352  0.016001 -0.949561  0.109088  0.803644
# 3886 -0.083897 -1.108528  0.370505 -1.703276  0.761291 -1.640151  0.405158
# 5437  0.873736  1.435924  0.085405  1.708097 -0.153930 -0.010485 -0.197144
# ...        ...       ...       ...       ...       ...       ...       ...
# 3919  1.119647 -0.676649 -1.378813  1.282400  0.252782 -0.806165  0.736645
# 162  -1.079305 -0.810049  1.028741  0.335451 -0.166739  0.337167  0.990843
# 7903  0.947686 -1.664634 -1.648833  0.529806 -1.529425  1.585409  0.092216
# 2242 -1.121653  0.192092 -0.237880  0.419095 -1.170887  0.734641  0.027815
# 2745 -1.379218  1.509286  0.280679  1.504603  0.654685 -1.489085 -0.783082
#
#             p4        g1        g2        g3        g4
# 9953  1.573327 -0.905890  1.168810 -1.504371  1.085038
# 3850  1.033273 -1.631674 -0.395717  1.414251  1.226315
# 4962  0.736607  1.455708 -1.439662  0.652298 -1.681693
# 3886 -0.087332  0.079893 -1.673738 -0.356077  1.056180
# 5437  0.474998  0.133199 -1.470930  0.956523 -0.819303
# ...        ...       ...       ...       ...       ...
# 3919 -0.369550  0.482951 -0.115287 -1.262003 -1.282666
# 162  -1.038393  0.950240  0.894080 -1.060055 -1.093674
# 7903  0.978910 -1.239338  0.126890  0.574012  1.319649
# 2242  1.271317  1.523035  0.795297 -1.359530 -0.801548
# 2745  1.135011  0.490514 -0.918109  0.004173  1.189330
#
# [2000 rows x 12 columns]

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
encoder.fit(y)
# Out:
# LabelEncoder()

# %%
y_train_encoded = encoder.transform(y_train)
y_train_encoded
# Out:
# array([1, 1, 1, ..., 1, 1, 0])

# %%
encoder.transform(['unstable'])
# Out:
# array([1], dtype=int64)

# %%
encoder.transform(['stable'])
# Out:
# array([0], dtype=int64)

# %%
y_test_encoded = encoder.transform(y_test)
y_test_encoded
# Out:
# array([1, 1, 0, ..., 0, 1, 1])

# %%
y_train_scaled = scaler.fit_transform(np.array(y_train_encoded).reshape(-1,1))
y_train_scaled
# Out:
# array([[ 0.75570623],
#        [ 0.75570623],
#        [ 0.75570623],
#        ...,
#        [ 0.75570623],
#        [ 0.75570623],
#        [-1.32326552]])

# %%
y_test_scaled = scaler.fit_transform(np.array(y_test_encoded).reshape(-1,1))
y_test_scaled
# Out:
# array([[ 0.74350187],
#        [ 0.74350187],
#        [-1.34498653],
#        ...,
#        [-1.34498653],
#        [ 0.74350187],
#        [ 0.74350187]])

# %%
len(y_train_scaled)
# Out:
# 8000

# %%
len(y_test_scaled)
# Out:
# 2000

# %%
rf_clf = RandomForestClassifier(random_state=1)

# %%
rf_clf.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=1, verbose=0,
#                        warm_start=False)

# %%
rf_pred = rf_clf.predict(X_test_scaled)

# %%
rf_accuracy_score = accuracy_score(y_test, rf_pred)
rf_accuracy_score
# Out:
# 0.929

# %%
rf_precision_score = precision_score(y_test, rf_pred, pos_label='stable')
rf_precision_score
# Out:
# 0.9191176470588235

# %%
rf_precision_score = precision_score(y_test, rf_pred, pos_label='unstable')
rf_precision_score
# Out:
# 0.9340909090909091

# %%
rf_precision_score = precision_score(y_test, rf_pred, average='weighted')
rf_precision_score
# Out:
# 0.9287604278074866

# %%
rf_recall_score = recall_score(y_test, rf_pred, pos_label='stable')
rf_recall_score
# Out:
# 0.8778089887640449

# %%
rf_recall_score = recall_score(y_test, rf_pred, pos_label='unstable')
rf_recall_score
# Out:
# 0.9572981366459627

# %%
rf_recall_score = recall_score(y_test, rf_pred, average='weighted')
rf_recall_score
# Out:
# 0.929

# %%
rf_f1 = f1_score(y_test, rf_pred, pos_label='stable')
rf_f1
# Out:
# 0.8979885057471264

# %%
rf_f1 = f1_score(y_test, rf_pred, pos_label='unstable')
rf_f1
# Out:
# 0.9455521472392638

# %%
rf_f1 = f1_score(y_test, rf_pred, average='weighted')
rf_f1
# Out:
# 0.928619490868063

# %%
et_clf = ExtraTreesClassifier(random_state=1)

# %%
et_clf.fit(X_train_scaled, y_train)
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100,
#                      n_jobs=None, oob_score=False, random_state=1, verbose=0,
#                      warm_start=False)

# %%
et_pred = et_clf.predict(X_test_scaled)

# %%
et_accuracy_score = accuracy_score(y_test, et_pred)
et_accuracy_score
# Out:
# 0.928

# %%
et_precision_score = precision_score(y_test, et_pred, pos_label='stable')
et_precision_score
# Out:
# 0.9409937888198758

# %%
et_precision_score = precision_score(y_test, et_pred, pos_label='unstable')
et_precision_score
# Out:
# 0.9218289085545722

# %%
et_precision_score = precision_score(y_test, et_pred, average='weighted')
et_precision_score
# Out:
# 0.9286516059290203

# %%
et_recall_score = recall_score(y_test, et_pred, pos_label='stable')
et_recall_score
# Out:
# 0.851123595505618

# %%
et_recall_score = recall_score(y_test, et_pred, pos_label='unstable')
et_recall_score
# Out:
# 0.9704968944099379

# %%
et_recall_score = recall_score(y_test, et_pred, average='weighted')
et_recall_score
# Out:
# 0.928

# %%
et_f1 = f1_score(y_test, et_pred, pos_label='stable')
et_f1
# Out:
# 0.8938053097345133

# %%
et_f1 = f1_score(y_test, et_pred, pos_label='unstable')
et_f1
# Out:
# 0.9455370650529501

# %%
et_f1 = f1_score(y_test, et_pred, average='weighted')
et_f1
# Out:
# 0.9271205601595865

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
n_estimators = [50, 100, 300, 500, 1000]
min_samples_split = [2, 3, 5, 7, 9]
min_samples_leaf = [1, 2, 4, 6, 8]
max_features = ['auto', 'sqrt', 'log2', None] 

hyperparameter_grid = {'n_estimators': n_estimators, 'min_samples_leaf': min_samples_leaf, 'min_samples_split': min_samples_split, 'max_features': max_features}

# %%
et_clf_2 = ExtraTreesClassifier(random_state=1)

# %%
rscv_clf = RandomizedSearchCV(et_clf_2, param_distributions=hyperparameter_grid, random_state=1)

# %%
rscv_clf.fit(X_train_scaled, y_train)
# Out:
# RandomizedSearchCV(cv=None, error_score=nan,
#                    estimator=ExtraTreesClassifier(bootstrap=False,
#                                                   ccp_alpha=0.0,
#                                                   class_weight=None,
#                                                   criterion='gini',
#                                                   max_depth=None,
#                                                   max_features='auto',
#                                                   max_leaf_nodes=None,
#                                                   max_samples=None,
#                                                   min_impurity_decrease=0.0,
#                                                   min_impurity_split=None,
#                                                   min_samples_leaf=1,
#                                                   min_samples_split=2,
#                                                   min_weight_fraction_leaf=0.0,
#                                                   n_estimators=100, n_jo...
#                                                   oob_score=False,
#                                                   random_state=1, verbose=0,
#                                                   warm_start=False),
#                    iid='deprecated', n_iter=10, n_jobs=None,
#                    param_distributions={'max_features': ['auto', 'sqrt', 'log2',
#                                                          None],
#                                         'min_samples_leaf': [1, 2, 4, 6, 8],
#                                         'min_samples_split': [2, 3, 5, 7, 9],
#                                         'n_estimators': [50, 100, 300, 500,
#                                                          1000]},
#                    pre_dispatch='2*n_jobs', random_state=1, refit=True,
#                    return_train_score=False, scoring=None, verbose=0)

# %%
rscv_clf.best_params_
# Out:
# {'n_estimators': 1000,
#  'min_samples_split': 2,
#  'min_samples_leaf': 8,
#  'max_features': None}

# %%
et_clf_3 = ExtraTreesClassifier(n_estimators=1000, min_samples_split=2, min_samples_leaf=8, max_features= None, random_state=1)

# %%
et_clf_3.fit(X_train_scaled, y_train)
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features=None,
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=8, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=1000,
#                      n_jobs=None, oob_score=False, random_state=1, verbose=0,
#                      warm_start=False)

# %%
et_pred_3 = et_clf_3.predict(X_test_scaled)

# %%
et_accuracy_score_3 = accuracy_score(y_test, et_pred_3)
et_accuracy_score_3
# Out:
# 0.927

# %%
et_clf_3.feature_importances_
# Out:
# array([0.13723982, 0.1405075 , 0.13468028, 0.13541676, 0.00368342,
#        0.0053368 , 0.00542927, 0.00496249, 0.10256244, 0.10757764,
#        0.11306268, 0.10954089])

# %%
importance = et_clf_3.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()
# Out:
# Feature: 0, Score: 0.13724
# Feature: 1, Score: 0.14051
# Feature: 2, Score: 0.13468
# Feature: 3, Score: 0.13542
# Feature: 4, Score: 0.00368
# Feature: 5, Score: 0.00534
# Feature: 6, Score: 0.00543
# Feature: 7, Score: 0.00496
# Feature: 8, Score: 0.10256
# Feature: 9, Score: 0.10758
# Feature: 10, Score: 0.11306
# Feature: 11, Score: 0.10954

# %%
xgb_clf = xgb.XGBClassifier(random_state=1)

# %%
xgb_clf.fit(X_train_scaled, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=0, num_parallel_tree=1,
#               objective='binary:logistic', random_state=1, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
xgb_pred = xgb_clf.predict(X_test_scaled)

# %%
xgb_accuracy_score = accuracy_score(y_test, xgb_pred)
xgb_accuracy_score
# Out:
# 0.9455

# %%
xgb_precision_score = precision_score(y_test, xgb_pred, pos_label='stable')
xgb_precision_score
# Out:
# 0.935064935064935

# %%
xgb_precision_score = precision_score(y_test, xgb_pred, pos_label='unstable')
xgb_precision_score
# Out:
# 0.9510328997704667

# %%
xgb_precision_score = precision_score(y_test, xgb_pred, average='weighted')
xgb_precision_score
# Out:
# 0.9453483043352974

# %%
xgb_recall_score = recall_score(y_test, xgb_pred, pos_label='stable')
xgb_recall_score
# Out:
# 0.9101123595505618

# %%
xgb_recall_score = recall_score(y_test, xgb_pred, pos_label='unstable')
xgb_recall_score
# Out:
# 0.9650621118012422

# %%
xgb_recall_score = recall_score(y_test, xgb_pred, average='weighted')
xgb_recall_score
# Out:
# 0.9455

# %%
xgb_f1 = f1_score(y_test, xgb_pred, pos_label='stable')
xgb_f1
# Out:
# 0.9224199288256227

# %%
xgb_f1 = f1_score(y_test, xgb_pred, pos_label='unstable')
xgb_f1
# Out:
# 0.9579961464354528

# %%
xgb_f1 = f1_score(y_test, xgb_pred, average='weighted')
xgb_f1
# Out:
# 0.9453310129663534

# %%
lgb_clf = lgb.LGBMClassifier(random_state=1)

# %%
lgb_clf.fit(X_train_scaled, y_train)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=1, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
lgb_pred = lgb_clf.predict(X_test_scaled)

# %%
lgb_accuracy_score = accuracy_score(y_test, lgb_pred)
lgb_accuracy_score
# Out:
# 0.9475

# %%
lgb_precision_score = precision_score(y_test, lgb_pred, pos_label='stable')
lgb_precision_score
# Out:
# 0.9392185238784371

# %%
lgb_precision_score = precision_score(y_test, lgb_pred, pos_label='unstable')
lgb_precision_score
# Out:
# 0.9518716577540107

# %%
lgb_precision_score = precision_score(y_test, lgb_pred, average='weighted')
lgb_precision_score
# Out:
# 0.9473671420943065

# %%
lgb_recall_score = recall_score(y_test, lgb_pred, pos_label='stable')
lgb_recall_score
# Out:
# 0.9115168539325843

# %%
lgb_recall_score = recall_score(y_test, lgb_pred, pos_label='unstable')
lgb_recall_score
# Out:
# 0.967391304347826

# %%
lgb_recall_score = recall_score(y_test, lgb_pred, average='weighted')
lgb_recall_score
# Out:
# 0.9475

# %%
lgb_f1 = f1_score(y_test, lgb_pred, pos_label='stable')
lgb_f1
# Out:
# 0.925160370634355

# %%
lgb_f1 = f1_score(y_test, lgb_pred, pos_label='unstable')
lgb_f1
# Out:
# 0.9595687331536389

# %%
lgb_f1 = f1_score(y_test, lgb_pred, average='weighted')
lgb_f1
# Out:
# 0.9473193560967739
